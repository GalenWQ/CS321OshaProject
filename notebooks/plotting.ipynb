# %% [markdown]
# # Plotting

# %%
import pandas as pd
import seaborn as sns; sns.set_style("whitegrid")

# %%
def prep_data():
    data.index.name = 'fold'
    data = data.reset_index()
    data['fold'] += 1

# %%
data = pd.read_json('all_results.json')
data.index.name = 'fold'
data = data.reset_index()
data['fold'] += 1

# %%
p = make_precision_plot(data)

# %%
p.savefig('images/dec_tree_prec.png')

# %%
def make_precision_plot(data, ylim=None):
    
    cols = ['overall_precision', 'majority_count']
    
    melted_data = data.melt(
        id_vars='fold',
        value_vars=cols)
    
    p = sns.factorplot(
        x="fold", y="value", hue='variable',
        data=melted_data, size=10,)
    if ylim:
        p.set(ylim=ylim)
        
    return p

# %%
def make_all_metrics_plot(data):
    
    cols = [
        'compliant_f1', 'compliant_precision', 'compliant_recall',
        'noncompliant_f1', 'noncompliant_precision', 'noncompliant_recall',
        'safe_f1', 'safe_precision', 'safe_recall']
    
    melted_df = data.melt(
        id_vars='fold',
        value_vars=cols)
    
    new = melted_df.variable.str.split('_', expand=True)
    new.columns = ['class', 'metric']
    df = pd.concat([melted_df, new], axis=1)
    
    p = sns.factorplot(
        x="fold", y="value",
        col='metric', hue='class',
        data=df, size=10)
    
    return p

# %%
p = make_all_metrics_plot(data)

# %%
p.savefig('images/dec_tree_all_metrics.png')

# %%
g = sns.factorplot(
    x="fold", y="value",
    col='metric', hue='class',
    data=df, size=6)
g.savefig('images/dec_tree_metrics.png')

# %%
def make_precision_plot(cols, ylim=None, split=False):
    
    melted_data = data.melt(
        id_vars='fold',
        value_vars=cols)
    
    if split:
        new = melted_df.variable.str.split('_', expand=True)
        new.columns = ['class', 'metric']
        df = pd.concat([melted_df, new], axis=1)
    
    g = sns.factorplot(
        x="fold", y="value", kind='point',
        hue='variable', data=melted_data, size=10,
        saturation=.5)
    if ylim:
        g.set(ylim=ylim)
        
    return g

# %%
cols = ['overall_precision', 'majority_count']
p = make_plot(cols, ylim=(0.8,.9))
p.savefig('images/dec_tree_overall.png')

# %%
cols = [
    'compliant_f1', 'compliant_precision', 'compliant_recall',
    'noncompliant_f1', 'noncompliant_precision', 'noncompliant_recall',
    'safe_f1', 'safe_precision', 'safe_recall']

# %%
melted_df = data.melt(
        id_vars='fold',
        value_vars=cols)

# %%
melted_df.head()
# Out:
#    fold      variable  value
# 0     1  compliant_f1    0.0
# 1     2  compliant_f1    0.0
# 2     3  compliant_f1    0.0
# 3     4  compliant_f1    0.0
# 4     5  compliant_f1    0.0

# %%
new = melted_df.variable.str.split('_', expand=True)
new.columns = ['class', 'metric']
df = pd.concat([melted_df, new], axis=1)

# %%
df.head()
# Out:
#    fold      variable  value      class metric
# 0     1  compliant_f1    0.0  compliant     f1
# 1     2  compliant_f1    0.0  compliant     f1
# 2     3  compliant_f1    0.0  compliant     f1
# 3     4  compliant_f1    0.0  compliant     f1
# 4     5  compliant_f1    0.0  compliant     f1

# %%
g = sns.factorplot(
    x="fold", y="value",
    col='metric', hue='class',
    data=df, size=6)
g.savefig('images/dec_tree_metrics.png')

# %% [markdown]
# ## K Means

# %%
def make_df_from_cluster_list(clusters):
    
    frames = []
    cols = ['heatmister_id', 'distance', 'speed', 'location', 'osha']

    for i, cluster in enumerate(clusters):
        df = pd.DataFrame(cluster, columns=cols)
        df['cluster'] = i
        frames.append(df)

    df = pd.concat(frames, ignore_index=True)
    df['distance'] = df['distance'].astype('float')
    df['speed'] = df['speed'].astype(int)
    
    return df

# %%
from osha import main

# %%
cp = main();
# Out:
# FOLD 1
# ______________________________________________________
# Precision (safe): 0.8693467336683417
# Recall (safe): 1.0
# F1 (safe): 0.9301075268817204
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.1111111111111111
# F1 (noncompliant): 0.19999999999999998
# -----------------------
# Precision (average): 0.9564489112227806
# Recall (average): 0.3703703703703704
# F1 (average): 0.3767025089605735
# -----------------------
# Precision (overall): 0.87
# Majority count: 0.865
# ______________________________________________________
#
# FOLD 2
# ______________________________________________________
# Precision (safe): 0.845
# Recall (safe): 1.0
# F1 (safe): 0.9159891598915989
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.0
# F1 (noncompliant): 0.0
# -----------------------
# Precision (average): 0.9483333333333333
# Recall (average): 0.3333333333333333
# F1 (average): 0.3053297199638663
# -----------------------
# Precision (overall): 0.845
# Majority count: 0.845
# ______________________________________________________
#
# FOLD 3
# ______________________________________________________
# Precision (safe): 0.8793969849246231
# Recall (safe): 1.0
# F1 (safe): 0.9358288770053477
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.10526315789473684
# F1 (noncompliant): 0.1904761904761905
# -----------------------
# Precision (average): 0.9597989949748743
# Recall (average): 0.3684210526315789
# F1 (average): 0.3754350224938461
# -----------------------
# Precision (overall): 0.88
# Majority count: 0.875
# ______________________________________________________
#
# FOLD 4
# ______________________________________________________
# Precision (safe): 0.8542713567839196
# Recall (safe): 1.0
# F1 (safe): 0.921409214092141
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.14285714285714285
# F1 (noncompliant): 0.25
# -----------------------
# Precision (average): 0.9514237855946398
# Recall (average): 0.38095238095238093
# F1 (average): 0.39046973803071366
# -----------------------
# Precision (overall): 0.855
# Majority count: 0.85
# ______________________________________________________
#
# FOLD 5
# ______________________________________________________
# Precision (safe): 0.8589420654911839
# Recall (safe): 1.0
# F1 (safe): 0.924119241192412
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.16666666666666666
# F1 (noncompliant): 0.2857142857142857
# -----------------------
# Precision (average): 0.9529806884970613
# Recall (average): 0.3888888888888889
# F1 (average): 0.4032778423022325
# -----------------------
# Precision (overall): 0.86
# Majority count: 0.8525
# ______________________________________________________
#
# FOLD 6
# ______________________________________________________
# Precision (safe): 0.8841309823677582
# Recall (safe): 1.0
# F1 (safe): 0.9385026737967915
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.1875
# F1 (noncompliant): 0.3157894736842105
# -----------------------
# Precision (average): 0.961376994122586
# Recall (average): 0.3958333333333333
# F1 (average): 0.41809738249366735
# -----------------------
# Precision (overall): 0.885
# Majority count: 0.8775
# ______________________________________________________
#
# FOLD 7
# ______________________________________________________
# Precision (safe): 0.8575
# Recall (safe): 1.0
# F1 (safe): 0.9232839838492598
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.0
# F1 (noncompliant): 0.0
# -----------------------
# Precision (average): 0.9525
# Recall (average): 0.3333333333333333
# F1 (average): 0.30776132794975325
# -----------------------
# Precision (overall): 0.8575
# Majority count: 0.8575
# ______________________________________________________
#
# FOLD 8
# ______________________________________________________
# Precision (safe): 0.8825
# Recall (safe): 1.0
# F1 (safe): 0.9375830013280213
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.0
# F1 (noncompliant): 0.0
# -----------------------
# Precision (average): 0.9608333333333333
# Recall (average): 0.3333333333333333
# F1 (average): 0.31252766710934043
# -----------------------
# Precision (overall): 0.8825
# Majority count: 0.8825
# ______________________________________________________
#
# FOLD 9
# ______________________________________________________
# Precision (safe): 0.8567839195979899
# Recall (safe): 1.0
# F1 (safe): 0.9228687415426252
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.1
# F1 (noncompliant): 0.18181818181818182
# -----------------------
# Precision (average): 0.9522613065326633
# Recall (average): 0.3666666666666667
# F1 (average): 0.3682289744536023
# -----------------------
# Precision (overall): 0.8575
# Majority count: 0.8525
# ______________________________________________________
#
# FOLD 10
# ______________________________________________________
# Precision (safe): 0.8325
# Recall (safe): 1.0
# F1 (safe): 0.9085948158253752
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.0
# F1 (noncompliant): 0.0
# -----------------------
# Precision (average): 0.9441666666666667
# Recall (average): 0.3333333333333333
# F1 (average): 0.30286493860845837
# -----------------------
# Precision (overall): 0.8325
# Majority count: 0.8325
# ______________________________________________________
#
# AVERAGE OF ALL FOLDS
# ______________________________________________________
# Precision (safe): 0.8620372042833816
# Recall (safe): 1.0
# F1 (safe): 0.9258287235405295
# -----------------------
# Precision (compliant): 1.0
# Recall (compliant): 0.0
# F1 (compliant): 0.0
# -----------------------
# Precision (noncompliant): 1.0
# Recall (noncompliant): 0.08133980785296574
# F1 (noncompliant): 0.14237981316928686
# -----------------------
# Precision (average): 0.9540124014277938
# Recall (average): 0.36044660261765527
# F1 (average): 0.35606951223660543
# -----------------------
# Precision (overall): 0.8625
# ______________________________________________________
#
# FOLD 1
# -----------------------
#
# CLUSTER 1
# Safe: 0.9914821124361158
# Compliant: 0.0068143100511073255
# NonCompliant: 0.0017035775127768314
# -----------------------
#
# CLUSTER 2
# Safe: 0.9893617021276596
# Compliant: 0.005319148936170213
# NonCompliant: 0.005319148936170213
# -----------------------
#
# CLUSTER 3
# Safe: 0.016853932584269662
# Compliant: 0.7780898876404494
# NonCompliant: 0.2050561797752809
# -----------------------
#
# CLUSTER 4
# Safe: 0.9744408945686901
# Compliant: 0.022364217252396165
# NonCompliant: 0.003194888178913738
# -----------------------
#
# CLUSTER 5
# Safe: 0.9376693766937669
# Compliant: 0.04878048780487805
# NonCompliant: 0.013550135501355014
# -----------------------
#
# CLUSTER 6
# Safe: 0.7241379310344828
# Compliant: 0.12643678160919541
# NonCompliant: 0.14942528735632185
# -----------------------
#
# CLUSTER 7
# Safe: 0.9770114942528736
# Compliant: 0.022988505747126436
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 8
# Safe: 0.9837133550488599
# Compliant: 0.009771986970684038
# NonCompliant: 0.006514657980456026
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 2
# -----------------------
#
# CLUSTER 1
# Safe: 0.9974554707379135
# Compliant: 0.0
# NonCompliant: 0.002544529262086514
# -----------------------
#
# CLUSTER 2
# Safe: 0.02564102564102564
# Compliant: 0.8632478632478633
# NonCompliant: 0.1111111111111111
# -----------------------
#
# CLUSTER 3
# Safe: 0.00847457627118644
# Compliant: 0.4915254237288136
# NonCompliant: 0.5
# -----------------------
#
# CLUSTER 4
# Safe: 0.03424657534246575
# Compliant: 0.9657534246575342
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 1.0
# Compliant: 0.0
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 6
# Safe: 0.9937578027465668
# Compliant: 0.003745318352059925
# NonCompliant: 0.0024968789013732834
# -----------------------
#
# CLUSTER 7
# Safe: 0.8310439560439561
# Compliant: 0.08516483516483517
# NonCompliant: 0.08379120879120878
# -----------------------
#
# CLUSTER 8
# Safe: 0.9953379953379954
# Compliant: 0.0011655011655011655
# NonCompliant: 0.0034965034965034965
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 3
# -----------------------
#
# CLUSTER 1
# Safe: 0.9975124378109452
# Compliant: 0.0
# NonCompliant: 0.0024875621890547263
# -----------------------
#
# CLUSTER 2
# Safe: 0.032520325203252036
# Compliant: 0.8780487804878049
# NonCompliant: 0.08943089430894309
# -----------------------
#
# CLUSTER 3
# Safe: 0.007692307692307693
# Compliant: 0.5
# NonCompliant: 0.49230769230769234
# -----------------------
#
# CLUSTER 4
# Safe: 0.05
# Compliant: 0.95
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 0.9954022988505747
# Compliant: 0.0022988505747126436
# NonCompliant: 0.0022988505747126436
# -----------------------
#
# CLUSTER 6
# Safe: 0.9922380336351876
# Compliant: 0.0038809831824062097
# NonCompliant: 0.0038809831824062097
# -----------------------
#
# CLUSTER 7
# Safe: 0.8393351800554016
# Compliant: 0.0817174515235457
# NonCompliant: 0.07894736842105263
# -----------------------
#
# CLUSTER 8
# Safe: 0.9942857142857143
# Compliant: 0.001142857142857143
# NonCompliant: 0.004571428571428572
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 4
# -----------------------
#
# CLUSTER 1
# Safe: 0.9941860465116279
# Compliant: 0.0029069767441860465
# NonCompliant: 0.0029069767441860465
# -----------------------
#
# CLUSTER 2
# Safe: 0.042735042735042736
# Compliant: 0.8717948717948718
# NonCompliant: 0.08547008547008547
# -----------------------
#
# CLUSTER 3
# Safe: 0.0
# Compliant: 0.4628099173553719
# NonCompliant: 0.5371900826446281
# -----------------------
#
# CLUSTER 4
# Safe: 0.034013605442176874
# Compliant: 0.9659863945578231
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 0.995475113122172
# Compliant: 0.0022624434389140274
# NonCompliant: 0.0022624434389140274
# -----------------------
#
# CLUSTER 6
# Safe: 0.9940334128878282
# Compliant: 0.003579952267303103
# NonCompliant: 0.002386634844868735
# -----------------------
#
# CLUSTER 7
# Safe: 0.8416666666666667
# Compliant: 0.08055555555555556
# NonCompliant: 0.07777777777777778
# -----------------------
#
# CLUSTER 8
# Safe: 0.9942594718714122
# Compliant: 0.001148105625717566
# NonCompliant: 0.004592422502870264
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 5
# -----------------------
#
# CLUSTER 1
# Safe: 1.0
# Compliant: 0.0
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 2
# Safe: 0.03389830508474576
# Compliant: 0.847457627118644
# NonCompliant: 0.11864406779661017
# -----------------------
#
# CLUSTER 3
# Safe: 0.0
# Compliant: 0.47058823529411764
# NonCompliant: 0.5294117647058824
# -----------------------
#
# CLUSTER 4
# Safe: 0.039473684210526314
# Compliant: 0.9605263157894737
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 0.9929577464788732
# Compliant: 0.004694835680751174
# NonCompliant: 0.002347417840375587
# -----------------------
#
# CLUSTER 6
# Safe: 0.9927797833935018
# Compliant: 0.0036101083032490976
# NonCompliant: 0.0036101083032490976
# -----------------------
#
# CLUSTER 7
# Safe: 0.8430555555555556
# Compliant: 0.08055555555555556
# NonCompliant: 0.0763888888888889
# -----------------------
#
# CLUSTER 8
# Safe: 0.9930875576036866
# Compliant: 0.001152073732718894
# NonCompliant: 0.00576036866359447
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 6
# -----------------------
#
# CLUSTER 1
# Safe: 0.9969788519637462
# Compliant: 0.0
# NonCompliant: 0.0030211480362537764
# -----------------------
#
# CLUSTER 2
# Safe: 0.03968253968253968
# Compliant: 0.8492063492063492
# NonCompliant: 0.1111111111111111
# -----------------------
#
# CLUSTER 3
# Safe: 0.0
# Compliant: 0.48717948717948717
# NonCompliant: 0.5128205128205128
# -----------------------
#
# CLUSTER 4
# Safe: 0.03896103896103896
# Compliant: 0.961038961038961
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 0.9955456570155902
# Compliant: 0.0022271714922048997
# NonCompliant: 0.0022271714922048997
# -----------------------
#
# CLUSTER 6
# Safe: 0.9951807228915662
# Compliant: 0.0012048192771084338
# NonCompliant: 0.0036144578313253013
# -----------------------
#
# CLUSTER 7
# Safe: 0.8354253835425384
# Compliant: 0.08507670850767085
# NonCompliant: 0.0794979079497908
# -----------------------
#
# CLUSTER 8
# Safe: 0.9931506849315068
# Compliant: 0.001141552511415525
# NonCompliant: 0.005707762557077625
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 7
# -----------------------
#
# CLUSTER 1
# Safe: 0.9973404255319149
# Compliant: 0.0
# NonCompliant: 0.0026595744680851063
# -----------------------
#
# CLUSTER 2
# Safe: 0.026785714285714284
# Compliant: 0.8482142857142857
# NonCompliant: 0.125
# -----------------------
#
# CLUSTER 3
# Safe: 0.008403361344537815
# Compliant: 0.48739495798319327
# NonCompliant: 0.5042016806722689
# -----------------------
#
# CLUSTER 4
# Safe: 0.0410958904109589
# Compliant: 0.958904109589041
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 0.995475113122172
# Compliant: 0.0022624434389140274
# NonCompliant: 0.0022624434389140274
# -----------------------
#
# CLUSTER 6
# Safe: 0.9927272727272727
# Compliant: 0.0036363636363636364
# NonCompliant: 0.0036363636363636364
# -----------------------
#
# CLUSTER 7
# Safe: 0.84
# Compliant: 0.08
# NonCompliant: 0.08
# -----------------------
#
# CLUSTER 8
# Safe: 0.9929824561403509
# Compliant: 0.0011695906432748538
# NonCompliant: 0.005847953216374269
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 8
# -----------------------
#
# CLUSTER 1
# Safe: 0.9975247524752475
# Compliant: 0.0
# NonCompliant: 0.0024752475247524753
# -----------------------
#
# CLUSTER 2
# Safe: 0.03571428571428571
# Compliant: 0.8571428571428571
# NonCompliant: 0.10714285714285714
# -----------------------
#
# CLUSTER 3
# Safe: 0.0
# Compliant: 0.46218487394957986
# NonCompliant: 0.5378151260504201
# -----------------------
#
# CLUSTER 4
# Safe: 0.03870967741935484
# Compliant: 0.9612903225806452
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 0.9926650366748166
# Compliant: 0.004889975550122249
# NonCompliant: 0.0024449877750611247
# -----------------------
#
# CLUSTER 6
# Safe: 0.9938347718865598
# Compliant: 0.0036991368680641184
# NonCompliant: 0.002466091245376079
# -----------------------
#
# CLUSTER 7
# Safe: 0.8359264497878359
# Compliant: 0.07920792079207921
# NonCompliant: 0.08486562942008487
# -----------------------
#
# CLUSTER 8
# Safe: 0.9932049830124575
# Compliant: 0.0011325028312570782
# NonCompliant: 0.0056625141562853904
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 9
# -----------------------
#
# CLUSTER 1
# Safe: 0.9975124378109452
# Compliant: 0.0
# NonCompliant: 0.0024875621890547263
# -----------------------
#
# CLUSTER 2
# Safe: 0.03418803418803419
# Compliant: 0.8547008547008547
# NonCompliant: 0.1111111111111111
# -----------------------
#
# CLUSTER 3
# Safe: 0.0
# Compliant: 0.48
# NonCompliant: 0.52
# -----------------------
#
# CLUSTER 4
# Safe: 0.039735099337748346
# Compliant: 0.9602649006622517
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 0.9954022988505747
# Compliant: 0.0022988505747126436
# NonCompliant: 0.0022988505747126436
# -----------------------
#
# CLUSTER 6
# Safe: 0.9923954372623575
# Compliant: 0.0038022813688212928
# NonCompliant: 0.0038022813688212928
# -----------------------
#
# CLUSTER 7
# Safe: 0.8391608391608392
# Compliant: 0.08111888111888112
# NonCompliant: 0.07972027972027972
# -----------------------
#
# CLUSTER 8
# Safe: 0.9942263279445728
# Compliant: 0.0011547344110854503
# NonCompliant: 0.004618937644341801
#
# Total length: 3600
# ______________________________________________________
#
# FOLD 10
# -----------------------
#
# CLUSTER 1
# Safe: 0.9944289693593314
# Compliant: 0.002785515320334262
# NonCompliant: 0.002785515320334262
# -----------------------
#
# CLUSTER 2
# Safe: 0.03305785123966942
# Compliant: 0.8760330578512396
# NonCompliant: 0.09090909090909091
# -----------------------
#
# CLUSTER 3
# Safe: 0.007633587786259542
# Compliant: 0.5190839694656488
# NonCompliant: 0.4732824427480916
# -----------------------
#
# CLUSTER 4
# Safe: 0.02877697841726619
# Compliant: 0.9712230215827338
# NonCompliant: 0.0
# -----------------------
#
# CLUSTER 5
# Safe: 0.9952941176470588
# Compliant: 0.002352941176470588
# NonCompliant: 0.002352941176470588
# -----------------------
#
# CLUSTER 6
# Safe: 0.9927184466019418
# Compliant: 0.0036407766990291263
# NonCompliant: 0.0036407766990291263
# -----------------------
#
# CLUSTER 7
# Safe: 0.8426966292134831
# Compliant: 0.07584269662921349
# NonCompliant: 0.08146067415730338
# -----------------------
#
# CLUSTER 8
# Safe: 0.9932508436445444
# Compliant: 0.0011248593925759281
# NonCompliant: 0.00562429696287964
#
# Total length: 3600
# ______________________________________________________

# %%
c_plotter = cp

# %%
dfs = []
for i, fold_df in enumerate(c_plotter.clusters):
    fold_df['fold'] = i
    dfs.append(fold_df)

# %%
data = pd.concat(dfs)

# %%
p = sns.lmplot(
    x='distance', y='speed', data=data,
    fit_reg=False, hue='cluster', col='fold', col_wrap=4)

# %%
p

# %%
frames = []
cols = ['heatmister_id', 'distance', 'speed', 'location', 'osha']

for i, cluster in enumerate(clusters):
    df = pd.DataFrame(cluster, columns=cols)
    df['cluster'] = i
    frames.append(df)

df = pd.concat(frames, ignore_index=True)
df['distance'] = df['distance'].astype('float')
df['speed'] = df['speed'].astype(int)

# %%
# pd.read_json('cluster.json')

# %%
df.head()
# Out:
#   heatmister_id  distance  speed location  osha  cluster
# 0     2018_3416     36.88      5   Office  Safe        0
# 1     2018_3578     33.32      8   Office  Safe        0
# 2      2018_569     38.96      4   Office  Safe        0
# 3     2018_2507     39.31      3   Office  Safe        0
# 4     2018_2437     36.80      4   Office  Safe        0

# %%
sns.lmplot(
    x='distance', y='speed', data=df,
    fit_reg=False, hue='cluster')

# %%
p =

# %%
p.get

# %%
d = df[['distance', 'speed', 'cluster']]

# %%
len(d)
# Out:
# 3430

# %%
d.head()
# Out:
#    distance  speed  cluster
# 0     36.88      5        0
# 1     33.32      8        0
# 2     38.96      4        0
# 3     39.31      3        0
# 4     36.80      4        0

# %%
sns.FacetGrid(d, 'distance', 'speed')

# %%
df

# %%
g = sns.jointplot(
    "distance", "speed", data=df,
    kind="kde", space=0, color="g")

# %%
import matplotlib.pyplot as plt
sns.set(style="darkgrid")

# %%
# Set up the figure
f, ax = plt.subplots(figsize=(16, 16))
ax.set_aspect("equal")

num_clusters = len(df.cluster.unique())
pal = sns.cubehelix_palette(n_colors=num_clusters)

for i in range(num_clusters):
    df_i = df[df['cluster']==i]
    ax = sns.kdeplot(
        df_i.distance, df_i.speed,
        shade=True, shade_lowest=False)
    
# ax.legend()
